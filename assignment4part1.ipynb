# %%
import tensorflow as tf
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow import keras

(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

scaled_train_images = train_images/255.0
scaled_test_images = test_images/255.0

val_set_size = math.ceil(scaled_train_images.shape[0]*.116)
scaled_val_images = scaled_train_images[:val_set_size]
val_labels = keras.utils.to_categorical(train_labels[:val_set_size], num_classes=10)
scaled_train_images = scaled_train_images[val_set_size:]
train_labels = keras.utils.to_categorical(train_labels[val_set_size:], num_classes=10)
encoded_test_labels = keras.utils.to_categorical(test_labels, num_classes=10)
print(f'scaled_val_images.shape: {scaled_val_images.shape}\nval_labels.shape: {val_labels.shape}\nscaled_train_images.shape: {scaled_train_images.shape}\ntrain_labels.shape: {train_labels.shape}\nscaled_test_images.shape: {scaled_test_images.shape}\nencoded_test_labels.shape: {encoded_test_labels.shape}')
# Out:
# scaled_val_images.shape: (6960, 28, 28)
# val_labels.shape: (6960, 10)
# scaled_train_images.shape: (53040, 28, 28)
# train_labels.shape: (53040, 10)
# scaled_test_images.shape: (10000, 28, 28)
# encoded_test_labels.shape: (10000, 10)

# %%
base_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape = (28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

base_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# Train the model (15 epo)
base_model_history = base_model.fit(scaled_train_images, train_labels, batch_size=32, epochs=30, verbose=1, validation_data=(scaled_val_images, val_labels))   

# scoring model
base_model_score = base_model.evaluate(scaled_test_images, encoded_test_labels, verbose=1)

# plotting loss curves
train_loss = base_model_history.history['loss']
val_loss = base_model_history.history['val_loss']
test_loss = base_model_score[0]

fig, ax = plt.subplots(1,3, figsize=(8,6))
ax[0].plot(range(1,31,1), train_loss, label='train_loss')
ax[0].plot(range(1,31,1), val_loss, label='val_loss')
ax[0].set_title('base model loss')
ax[0].set_xlabel('epoch')
ax[0].set_ylabel('loss')
ax[0].axhline(y=test_loss, color='red', label='test_loss')
plt.legend()
plt.tight_layout()

six_epoch_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape = (28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

six_epoch_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# Train the model
six_epoch_model_history = six_epoch_model.fit(scaled_train_images, train_labels, batch_size=32, epochs=6, verbose=1, validation_data=(scaled_val_images, val_labels))   

# scoring model
six_epoch_model_score = six_epoch_model.evaluate(scaled_test_images, test_labels, verbose=1)

# plotting loss curves
train_loss = six_epoch_model_history.history['loss']
val_loss = six_epoch_model_history.history['val_loss']
test_loss = six_epoch_model_score[0]

ax[1].plot(range(1,7,1), train_loss, label='train_loss')
ax[1].plot(range(1,7,1), val_loss, label='val_loss')
ax[1].axhline(y=test_loss, color='red', label='test_loss')
ax[1].set_title('6 epoch model loss')
ax[1].set_xlabel('epoch')
ax[1].set_ylabel('loss')
plt.legend()
plt.tight_layout()

filter_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (5, 5), activation='relu', input_shape = (28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (5,5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

filter_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# Train the model
filter_model_history = filter_model.fit(scaled_train_images, train_labels, batch_size=32, epochs=6, verbose=1, validation_data=(scaled_val_images, val_labels))

# scoring model
filter_model_score = filter_model.evaluate(scaled_test_images, test_labels, verbose=1)

# plotting loss curves
train_loss = filter_model_history.history['loss']
val_loss = filter_model_history.history['val_loss']
test_loss = filter_model_score[0]

ax[2].plot(range(1,7,1), train_loss, label='train_loss')
ax[2].plot(range(1,7,1), val_loss, label='val_loss')
ax[2].axhline(y=test_loss, color='red', label='test_loss')
ax[2].set_title('6 epoch + (5,5) filter size')
ax[2].set_xlabel('epoch')
ax[2].set_ylabel('loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/30
# c:\Users\jarre\ics 435 machine learning fundamentals\assignments\assignment4\.env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8326 - loss: 0.4540 - val_accuracy: 0.8871 - val_loss: 0.3220
# Epoch 2/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8922 - loss: 0.2975 - val_accuracy: 0.8955 - val_loss: 0.2936
# Epoch 3/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9056 - loss: 0.2547 - val_accuracy: 0.9096 - val_loss: 0.2599
# Epoch 4/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9165 - loss: 0.2294 - val_accuracy: 0.9119 - val_loss: 0.2504
# Epoch 5/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9235 - loss: 0.2072 - val_accuracy: 0.9093 - val_loss: 0.2613
# Epoch 6/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9310 - loss: 0.1908 - val_accuracy: 0.9161 - val_loss: 0.2522
# Epoch 7/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9362 - loss: 0.1734 - val_accuracy: 0.9136 - val_loss: 0.2499
# Epoch 8/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9421 - loss: 0.1611 - val_accuracy: 0.9079 - val_loss: 0.2731
# Epoch 9/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9467 - loss: 0.1493 - val_accuracy: 0.9115 - val_loss: 0.2772
# Epoch 10/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9481 - loss: 0.1414 - val_accuracy: 0.9174 - val_loss: 0.2678
# Epoch 11/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9531 - loss: 0.1306 - val_accuracy: 0.9174 - val_loss: 0.2637
# Epoch 12/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9557 - loss: 0.1224 - val_accuracy: 0.9177 - val_loss: 0.3270
# Epoch 13/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9589 - loss: 0.1147 - val_accuracy: 0.9161 - val_loss: 0.3157
# Epoch 14/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9607 - loss: 0.1094 - val_accuracy: 0.9161 - val_loss: 0.3409
# Epoch 15/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9625 - loss: 0.1064 - val_accuracy: 0.9014 - val_loss: 0.3654
# Epoch 16/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9639 - loss: 0.1013 - val_accuracy: 0.9121 - val_loss: 0.3497
# Epoch 17/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9676 - loss: 0.0922 - val_accuracy: 0.9116 - val_loss: 0.3421
# Epoch 18/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9678 - loss: 0.0903 - val_accuracy: 0.9072 - val_loss: 0.3710
# Epoch 19/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9693 - loss: 0.0855 - val_accuracy: 0.9155 - val_loss: 0.3886
# Epoch 20/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9709 - loss: 0.0817 - val_accuracy: 0.9112 - val_loss: 0.4732
# Epoch 21/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9722 - loss: 0.0793 - val_accuracy: 0.9184 - val_loss: 0.4678
# Epoch 22/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9724 - loss: 0.0781 - val_accuracy: 0.9161 - val_loss: 0.4308
# Epoch 23/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9742 - loss: 0.0732 - val_accuracy: 0.9151 - val_loss: 0.4659
# Epoch 24/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9751 - loss: 0.0706 - val_accuracy: 0.9072 - val_loss: 0.4666
# Epoch 25/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9746 - loss: 0.0713 - val_accuracy: 0.9106 - val_loss: 0.4285
# Epoch 26/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9772 - loss: 0.0655 - val_accuracy: 0.9135 - val_loss: 0.5958
# Epoch 27/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9779 - loss: 0.0640 - val_accuracy: 0.9126 - val_loss: 0.6193
# Epoch 28/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9789 - loss: 0.0629 - val_accuracy: 0.8920 - val_loss: 0.5757
# Epoch 29/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9798 - loss: 0.0580 - val_accuracy: 0.9095 - val_loss: 0.5513
# Epoch 30/30
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9804 - loss: 0.0587 - val_accuracy: 0.9089 - val_loss: 0.5888
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8990 - loss: 0.7128
# Epoch 1/6
# C:\Users\jarre\AppData\Local\Temp\ipykernel_28212\908976323.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8332 - loss: 0.4558 - val_accuracy: 0.8716 - val_loss: 0.3671
# Epoch 2/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8896 - loss: 0.2998 - val_accuracy: 0.8953 - val_loss: 0.2951
# Epoch 3/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9051 - loss: 0.2575 - val_accuracy: 0.9115 - val_loss: 0.2475
# Epoch 4/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9152 - loss: 0.2295 - val_accuracy: 0.9174 - val_loss: 0.2337
# Epoch 5/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9225 - loss: 0.2094 - val_accuracy: 0.9101 - val_loss: 0.2610
# Epoch 6/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9301 - loss: 0.1913 - val_accuracy: 0.8989 - val_loss: 0.3066
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8886 - loss: 0.3284
# Epoch 1/6
# C:\Users\jarre\AppData\Local\Temp\ipykernel_28212\908976323.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8344 - loss: 0.4591 - val_accuracy: 0.8899 - val_loss: 0.3077
# Epoch 2/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8918 - loss: 0.2965 - val_accuracy: 0.8971 - val_loss: 0.3001
# Epoch 3/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9062 - loss: 0.2592 - val_accuracy: 0.8937 - val_loss: 0.3109
# Epoch 4/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9145 - loss: 0.2347 - val_accuracy: 0.9046 - val_loss: 0.2772
# Epoch 5/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9230 - loss: 0.2147 - val_accuracy: 0.9066 - val_loss: 0.2768
# Epoch 6/6
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9288 - loss: 0.1995 - val_accuracy: 0.9030 - val_loss: 0.2814
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8927 - loss: 0.3145

# %%
# getting predictions

base_model_predictions = np.argmax(base_model.predict(scaled_test_images), axis=1).tolist()
six_expoch_model_predictions = np.argmax(six_epoch_model.predict(scaled_test_images), axis=1).tolist()
filter_model_predictions = np.argmax(filter_model.predict(scaled_test_images), axis=1).tolist()

# getting actual labels

labels =['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

actual_labels = [labels[item] for item in test_labels]

base_model_predicted_labels = [labels[item] for item in base_model_predictions]
six_epoch_model_predicted_labels = [labels[item] for item in six_expoch_model_predictions]
filter_model_predicted_labels = [labels[item] for item in filter_model_predictions]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.ticker import PercentFormatter

# If this variable name is a typo in your notebook, fix it here:
six_epoch_model_predicted_labels = [labels[item] for item in six_expoch_model_predictions]
filter_model_predicted_labels = [labels[item] for item in filter_model_predictions]

# Put all models in one place
model_predictions = [
    ("Base Model", base_model_predicted_labels),
    ("Six-Epoch Model", six_epoch_model_predicted_labels),
    ("Filter Model", filter_model_predicted_labels),
]

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(24, 7), dpi=200)

for ax, (model_name, preds) in zip(axes, model_predictions):
    # Confusion matrix and accuracy
    cm = confusion_matrix(actual_labels, preds, labels=labels)
    acc = accuracy_score(actual_labels, preds)

    # Row-normalized matrix for color shading
    cm_sum = cm.sum(axis=1, keepdims=True)
    cm_norm = np.divide(cm, cm_sum, where=cm_sum != 0)

    # Heatmap
    im = ax.imshow(cm_norm, interpolation='nearest', cmap='Blues', vmin=0, vmax=1)

    # Axis formatting
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels(labels, rotation=30, ha='right', fontsize=10)
    ax.set_yticklabels(labels, fontsize=10)
    ax.set_xlabel("Predicted label", fontsize=11)
    ax.set_ylabel("True label", fontsize=11)

    # Title
    ax.set_title(
        f"{model_name}\nAccuracy = {acc:.2%}",
        fontsize=15,
        fontweight='bold',
        pad=16
    )

    # White grid lines between cells
    ax.set_xticks(np.arange(cm.shape[1] + 1) - 0.5, minor=True)
    ax.set_yticks(np.arange(cm.shape[0] + 1) - 0.5, minor=True)
    ax.grid(which='minor', color='white', linestyle='-', linewidth=2)
    ax.tick_params(which='minor', bottom=False, left=False)

    # Annotate cells with count and row percentage
    threshold = cm_norm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            count = cm[i, j]
            pct = cm_norm[i, j]
            text_color = 'white' if pct > threshold else 'black'

            ax.text(
                j, i,
                f"{count}\n",
                ha='center', va='center',
                color=text_color,
                fontsize=10,
                fontweight='bold'
            )

    # Remove outer spines for cleaner look
    for spine in ax.spines.values():
        spine.set_visible(False)

# Shared colorbar
# cbar = fig.colorbar(im, ax=axes, fraction=0.02, pad=0.02)
# cbar.ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
# cbar.set_label("Row-normalized percentage", fontsize=12)

# Overall title
fig.suptitle(
    "Confusion Matrix Comparison Across Models",
    fontsize=20,
    fontweight='bold',
    y=1.03
)

fig.tight_layout()

# Optional save
# plt.savefig("confusion_matrix_comparison.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# C:\Users\jarre\AppData\Local\Temp\ipykernel_28212\1283767708.py:27: UserWarning: 'where' used without 'out', expect unitialized memory in output. If this is intentional, use out=None.
#   cm_norm = np.divide(cm, cm_sum, where=cm_sum != 0)
# C:\Users\jarre\AppData\Local\Temp\ipykernel_28212\1283767708.py:27: UserWarning: 'where' used without 'out', expect unitialized memory in output. If this is intentional, use out=None.
#   cm_norm = np.divide(cm, cm_sum, where=cm_sum != 0)
# C:\Users\jarre\AppData\Local\Temp\ipykernel_28212\1283767708.py:27: UserWarning: 'where' used without 'out', expect unitialized memory in output. If this is intentional, use out=None.
#   cm_norm = np.divide(cm, cm_sum, where=cm_sum != 0)
